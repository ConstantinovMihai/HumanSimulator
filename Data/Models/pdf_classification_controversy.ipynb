# %%
import numpy as np
from torch.utils.data import Dataset
import matplotlib.pyplot as plt
import numpy as np
from tsai.all import *
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, roc_curve, auc, confusion_matrix, roc_auc_score, f1_score, accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
from utils import *
from sklearn.neighbors import KernelDensity
import scipy as sp

# %% [markdown]
# ## Read data

# %%
error_not_distracted_list, u_signal_not_distracted_list = process_signals(error_file= r'/home/mihai/Thesis/Data/Clean_CSV_data/updated_data/PSN/e.csv', u_file=r'/home/mihai/Thesis/Data/Clean_CSV_data/updated_data/PSN/u.csv')
error_distracted_list, u_signal_distracted_list         = process_signals(error_file= r'/home/mihai/Thesis/Data/Clean_CSV_data/updated_data/PSDCE/e.csv', u_file=r'/home/mihai/Thesis/Data/Clean_CSV_data/updated_data/PSDCE/u.csv')

error_test, u_signal_test = process_signals(error_file= r'/home/mihai/Thesis/Data/Clean_CSV_data/updated_data/PSDPE/e.csv', u_file=r'/home/mihai/Thesis/Data/Clean_CSV_data/updated_data/PSDPE/u.csv')

person_idx = 1

# combine the entire list in the priors
error_not_distracted = np.concatenate(error_not_distracted_list[person_idx])
u_not_distracted = np.concatenate(u_signal_not_distracted_list[person_idx])

error_distracted = np.concatenate(error_distracted_list[person_idx])
u_distracted = np.concatenate(u_signal_distracted_list[person_idx])

error_test = np.concatenate(error_test[person_idx])
u_signal_test = np.concatenate(u_signal_test[person_idx])


tc_test = np.loadtxt(r'/home/mihai/Thesis/Data/Clean_CSV_data/updated_data/PSDPE/mdist.csv', delimiter=',')
print(f"{tc_test.shape=}; {error_test.shape=}; {u_signal_test.shape=}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 error_not_distracted_list, u_signal_not_distracted_list = process_signals(error_file= r'/home/mihai/Thesis/Data/Clean_CSV_data/updated_data/PSN/e.csv', u_file=r'/home/mihai/Thesis/Data/Clean_CSV_data/updated_data/PSN/u.csv')
#       2 error_distracted_list, u_signal_distracted_list         = process_signals(error_file= r'/home/mihai/Thesis/Data/Clean_CSV_data/updated_data/PSDCE/e.csv', u_file=r'/home/mihai/Thesis/Data/Clean_CSV_data/updated_data/PSDCE/u.csv')
#       4 error_test, u_signal_test = process_signals(error_file= r'/home/mihai/Thesis/Data/Clean_CSV_data/updated_data/PSDPE/e.csv', u_file=r'/home/mihai/Thesis/Data/Clean_CSV_data/updated_data/PSDPE/u.csv')
#
# TypeError: process_signals() missing 1 required positional argument: 'x_file'

# %% [markdown]
# ## Estimate piors' PDFs and Visualize

# %%
def estimate_distribution_single(data, bandwidth=0.1):
    kde = KernelDensity(kernel='gaussian', bandwidth=0.1).fit(data[:, None])
    return kde

# %%
# Function to visualize KDE and histogram for any signal
def plot_kde_histogram(data, title, color='lightblue', kde_color='red', bandwidth=0.2, bins=30):
    """
    Plots a histogram with KDE overlay for the given data.
    
    Parameters:
    data (numpy array): Input signal data to plot.
    title (str): Title of the plot.
    color (str): Color of the histogram.
    kde_color (str): Color of the KDE plot.
    bandwidth (float): Bandwidth for the KDE.
    bins (int): Number of bins in the histogram.
    """
    # Step 1: Plot histogram
    plt.hist(data, bins=bins, density=True, alpha=0.5, color=color, label='Histogram')

    # Step 2: Estimate the KDE
    kde = KernelDensity(kernel='gaussian', bandwidth=bandwidth).fit(data[:, None])

    # Create an array of values where KDE will be evaluated
    x_vals = np.linspace(data.min(), data.max(), 1000)

    # Step 3: Evaluate the KDE to get the probability densities
    log_density = kde.score_samples(x_vals[:, None])  # Returns log of density
    density = np.exp(log_density)  # Convert log density back to normal density

    # Step 4: Plot the KDE on top of the histogram
    plt.plot(x_vals, density, color=kde_color, label='KDE', linewidth=2)

    # Add labels and title
    plt.xlabel('Signal Values')
    plt.ylabel('Density')
    plt.title(title)
    plt.legend()

    # Show the plot
    plt.show()

# Visualize the error_signal
plot_kde_histogram(error_distracted, title='Error Signal "e" Distracted Distribution', bandwidth=0.07)

# Visualize the control input signal (u_signal)
plot_kde_histogram(error_not_distracted, title='Error Signal "e" Not Distracted Distribution', bandwidth=0.07)

# %%
# Visualize the error_signal
plot_kde_histogram(u_distracted, title='U Signal Distracted Distribution', bandwidth=0.07)

# Visualize the control input signal (u_signal)
plot_kde_histogram(u_not_distracted, title='U Signal Not Distracted "u" Distribution', bandwidth=0.07)

# %% [markdown]
# ## Generate windowed data

# %%
def create_windows(data, window_size=100, overlap=0.5):
    """
    Creates windows of the given data with the specified window size and overlap.
    
    Parameters:
    data (numpy array): Input signal data.
    window_size (int): Size of the window.
    overlap (float): Overlap between windows (0 to 1).
    
    Returns:
    numpy array: Array of windows with the given size and overlap.
    """
    step = int(window_size * (1 - overlap))
    return np.array([data[i:i + window_size] for i in range(0, len(data) - window_size + 1, step)])

error_test_windows =  create_windows(error_test, window_size=100, overlap=0.5)
u_test_windows = create_windows(u_signal_test, window_size=100, overlap=0.5)
tc_windows = create_windows(np.concatenate(tc_test[:,:4]), window_size=100, overlap=0.5)

# %% [markdown]
# ## Compare and classify incoming windows with prior data

# %%
def classify_windows(e_windows, u_windows, reference_kde_distracted, reference_kde_not_distracted):
    """
    Classify the windows as distracted or not distracted based on KL divergence
    from reference KDEs (distracted and not distracted distributions).
    
    Parameters:
    e_windows (list of arrays): Test windows of the error signal.
    u_windows (list of arrays): Test windows of the control input signal.
    reference_kde_distracted (KernelDensity): KDE for the distracted state.
    reference_kde_not_distracted (KernelDensity): KDE for the non-distracted state.
    
    Returns:
    list: Labels for each window (1 = distracted, 0 = not distracted).
    """
    labels = np.zeros(len(e_windows)) 
    kl_dist_list = []
    kl_not_dist_list = []

    for i in range(len(e_windows)):
        print(f"Processing window {i+1}/{len(e_windows)}")
        # Stack e and u into a multivariate window of shape (window_size, 2)
        window_data = np.column_stack((e_windows[i], u_windows[i]))  # Combine e and u

        # Fit KDE on the current window (multivariate KDE)
        kde_window = KernelDensity(kernel='gaussian', bandwidth=0.02).fit(window_data)
        
        # Score samples (log likelihoods) for each window
        window_log_scores = kde_window.score_samples(window_data)
        distracted_log_scores = reference_kde_distracted.score_samples(window_data)
        not_distracted_log_scores = reference_kde_not_distracted.score_samples(window_data)
        
        # Convert log likelihoods to probabilities (exponentiate)
        window_probs = np.exp(window_log_scores)
        distracted_probs = np.exp(distracted_log_scores)
        not_distracted_probs = np.exp(not_distracted_log_scores)
        
        # Compute KL divergence between current window and reference KDEs
        kl_dist = sp.stats.entropy(window_probs, distracted_probs)
        kl_not_dist = sp.stats.entropy(window_probs, not_distracted_probs)
        
        # Classify based on which divergence is smaller
        labels[i] = int(kl_dist < kl_not_dist)

        kl_dist_list.append(kl_dist)
        kl_not_dist_list.append(kl_not_dist)
    
    return labels, kl_dist_list, kl_not_dist_list

input_distracted = np.column_stack((error_distracted, u_distracted))  # Distracted data
input_not_distracted = np.column_stack((error_not_distracted, u_not_distracted))  # Non-distracted data

def estimate_distribution(data, bandwidth=0.1):
    kde = KernelDensity(kernel='gaussian', bandwidth=bandwidth)
    kde.fit(data)
    return kde

print(f"Start estimation distributions...")

# Fit KDEs for distracted and non-distracted states using the 2D data
kde_distracted = estimate_distribution(input_distracted, bandwidth=0.07)
kde_not_distracted = estimate_distribution(input_not_distracted, bandwidth=0.07)

print(f"Start classifying test windows...")

# Classify test windows based on multivariate KDE (both error and control signals)
test_labels, kl_dists, kl_not_dists = classify_windows(error_test_windows, u_test_windows, kde_distracted, kde_not_distracted)
# Out:
# Start estimation distributions...
# Start classifying test windows...
# Processing window 1/959
# Processing window 2/959
# Processing window 3/959
# Processing window 4/959
# Processing window 5/959
# Processing window 6/959
# Processing window 7/959
# Processing window 8/959
# Processing window 9/959
# Processing window 10/959
# Processing window 11/959
# Processing window 12/959
# Processing window 13/959
# Processing window 14/959
# Processing window 15/959
# Processing window 16/959
# Processing window 17/959
# Processing window 18/959
# Processing window 19/959
# Processing window 20/959
# Processing window 21/959
# Processing window 22/959
# Processing window 23/959
# Processing window 24/959
# Processing window 25/959
# Processing window 26/959
# Processing window 27/959
# Processing window 28/959
# Processing window 29/959
# Processing window 30/959
# Processing window 31/959
# Processing window 32/959
# Processing window 33/959
# Processing window 34/959
# Processing window 35/959
# Processing window 36/959
# Processing window 37/959
# Processing window 38/959
# Processing window 39/959
# Processing window 40/959
# Processing window 41/959
# Processing window 42/959
# Processing window 43/959
# Processing window 44/959
# Processing window 45/959
# Processing window 46/959
# Processing window 47/959
# Processing window 48/959
# Processing window 49/959
# Processing window 50/959
# Processing window 51/959
# Processing window 52/959
# Processing window 53/959
# Processing window 54/959
# Processing window 55/959
# Processing window 56/959
# Processing window 57/959
# Processing window 58/959
# Processing window 59/959
# Processing window 60/959
# Processing window 61/959
# Processing window 62/959
# Processing window 63/959
# Processing window 64/959
# Processing window 65/959
# Processing window 66/959
# Processing window 67/959
# Processing window 68/959
# Processing window 69/959
# Processing window 70/959
# Processing window 71/959
# Processing window 72/959
# Processing window 73/959
# Processing window 74/959
# Processing window 75/959
# Processing window 76/959
# Processing window 77/959
# Processing window 78/959
# Processing window 79/959
# Processing window 80/959
# Processing window 81/959
# Processing window 82/959
# Processing window 83/959
# Processing window 84/959
# Processing window 85/959
# Processing window 86/959
# Processing window 87/959
# Processing window 88/959
# Processing window 89/959
# Processing window 90/959
# Processing window 91/959
# Processing window 92/959
# Processing window 93/959
# Processing window 94/959
# Processing window 95/959
# Processing window 96/959
# Processing window 97/959
# Processing window 98/959
# Processing window 99/959
# Processing window 100/959
# Processing window 101/959
# Processing window 102/959
# Processing window 103/959
# Processing window 104/959
# Processing window 105/959
# Processing window 106/959
# Processing window 107/959
# Processing window 108/959
# Processing window 109/959
# Processing window 110/959
# Processing window 111/959
# Processing window 112/959
# Processing window 113/959
# Processing window 114/959
# Processing window 115/959
# Processing window 116/959
# Processing window 117/959
# Processing window 118/959
# Processing window 119/959
# Processing window 120/959
# Processing window 121/959
# Processing window 122/959
# Processing window 123/959
# Processing window 124/959
# Processing window 125/959
# Processing window 126/959
# Processing window 127/959
# Processing window 128/959
# Processing window 129/959
# Processing window 130/959
# Processing window 131/959
# Processing window 132/959
# Processing window 133/959
# Processing window 134/959
# Processing window 135/959
# Processing window 136/959
# Processing window 137/959
# Processing window 138/959
# Processing window 139/959
# Processing window 140/959
# Processing window 141/959
# Processing window 142/959
# Processing window 143/959
# Processing window 144/959
# Processing window 145/959
# Processing window 146/959
# Processing window 147/959
# Processing window 148/959
# Processing window 149/959
# Processing window 150/959
# Processing window 151/959
# Processing window 152/959
# Processing window 153/959
# Processing window 154/959
# Processing window 155/959
# Processing window 156/959
# Processing window 157/959
# Processing window 158/959
# Processing window 159/959
# Processing window 160/959
# Processing window 161/959
# Processing window 162/959
# Processing window 163/959
# Processing window 164/959
# Processing window 165/959
# Processing window 166/959
# Processing window 167/959
# Processing window 168/959
# Processing window 169/959
# Processing window 170/959
# Processing window 171/959
# Processing window 172/959
# Processing window 173/959
# Processing window 174/959
# Processing window 175/959
# Processing window 176/959
# Processing window 177/959
# Processing window 178/959
# Processing window 179/959
# Processing window 180/959
# Processing window 181/959
# Processing window 182/959
# Processing window 183/959
# Processing window 184/959
# Processing window 185/959
# Processing window 186/959
# Processing window 187/959
# Processing window 188/959
# Processing window 189/959
# Processing window 190/959
# Processing window 191/959
# Processing window 192/959
# Processing window 193/959
# Processing window 194/959
# Processing window 195/959
# Processing window 196/959
# Processing window 197/959
# Processing window 198/959
# Processing window 199/959
# Processing window 200/959
# Processing window 201/959
# Processing window 202/959
# Processing window 203/959
# Processing window 204/959
# Processing window 205/959
# Processing window 206/959
# Processing window 207/959
# Processing window 208/959
# Processing window 209/959
# Processing window 210/959
# Processing window 211/959
# Processing window 212/959
# Processing window 213/959
# Processing window 214/959
# Processing window 215/959
# Processing window 216/959
# Processing window 217/959
# Processing window 218/959
# Processing window 219/959
# Processing window 220/959
# Processing window 221/959
# Processing window 222/959
# Processing window 223/959
# Processing window 224/959
# Processing window 225/959
# Processing window 226/959
# Processing window 227/959
# Processing window 228/959
# Processing window 229/959
# Processing window 230/959
# Processing window 231/959
# Processing window 232/959
# Processing window 233/959
# Processing window 234/959
# Processing window 235/959
# Processing window 236/959
# Processing window 237/959
# Processing window 238/959
# Processing window 239/959
# Processing window 240/959
# Processing window 241/959
# Processing window 242/959
# Processing window 243/959
# Processing window 244/959
# Processing window 245/959
# Processing window 246/959
# Processing window 247/959
# Processing window 248/959
# Processing window 249/959
# Processing window 250/959
# Processing window 251/959
# Processing window 252/959
# Processing window 253/959
# Processing window 254/959
# Processing window 255/959
# Processing window 256/959
# Processing window 257/959
# Processing window 258/959
# Processing window 259/959
# Processing window 260/959
# Processing window 261/959
# Processing window 262/959
# Processing window 263/959
# Processing window 264/959
# Processing window 265/959
# Processing window 266/959
# Processing window 267/959
# Processing window 268/959
# Processing window 269/959
# Processing window 270/959
# Processing window 271/959
# Processing window 272/959
# Processing window 273/959
# Processing window 274/959
# Processing window 275/959
# Processing window 276/959
# Processing window 277/959
# Processing window 278/959
# Processing window 279/959
# Processing window 280/959
# Processing window 281/959
# Processing window 282/959
# Processing window 283/959
# Processing window 284/959
# Processing window 285/959
# Processing window 286/959
# Processing window 287/959
# Processing window 288/959
# Processing window 289/959
# Processing window 290/959
# Processing window 291/959
# Processing window 292/959
# Processing window 293/959
# Processing window 294/959
# Processing window 295/959
# Processing window 296/959
# Processing window 297/959
# Processing window 298/959
# Processing window 299/959
# Processing window 300/959
# Processing window 301/959
# Processing window 302/959
# Processing window 303/959
# Processing window 304/959
# Processing window 305/959
# Processing window 306/959
# Processing window 307/959
# Processing window 308/959
# Processing window 309/959
# Processing window 310/959
# Processing window 311/959
# Processing window 312/959
# Processing window 313/959
# Processing window 314/959
# Processing window 315/959
# Processing window 316/959
# Processing window 317/959
# Processing window 318/959
# Processing window 319/959
# Processing window 320/959
# Processing window 321/959
# Processing window 322/959
# Processing window 323/959
# Processing window 324/959
# Processing window 325/959
# Processing window 326/959
# Processing window 327/959
# Processing window 328/959
# Processing window 329/959
# Processing window 330/959
# Processing window 331/959
# Processing window 332/959
# Processing window 333/959
# Processing window 334/959
# Processing window 335/959
# Processing window 336/959
# Processing window 337/959
# Processing window 338/959
# Processing window 339/959
# Processing window 340/959
# Processing window 341/959
# Processing window 342/959
# Processing window 343/959
# Processing window 344/959
# Processing window 345/959
# Processing window 346/959
# Processing window 347/959
# Processing window 348/959
# Processing window 349/959
# Processing window 350/959
# Processing window 351/959
# Processing window 352/959
# Processing window 353/959
# Processing window 354/959
# Processing window 355/959
# Processing window 356/959
# Processing window 357/959
# Processing window 358/959
# Processing window 359/959
# Processing window 360/959
# Processing window 361/959
# Processing window 362/959
# Processing window 363/959
# Processing window 364/959
# Processing window 365/959
# Processing window 366/959
# Processing window 367/959
# Processing window 368/959
# Processing window 369/959
# Processing window 370/959
# Processing window 371/959
# Processing window 372/959
# Processing window 373/959
# Processing window 374/959
# Processing window 375/959
# Processing window 376/959
# Processing window 377/959
# Processing window 378/959
# Processing window 379/959
# Processing window 380/959
# Processing window 381/959
# Processing window 382/959
# Processing window 383/959
# Processing window 384/959
# Processing window 385/959
# Processing window 386/959
# Processing window 387/959
# Processing window 388/959
# Processing window 389/959
# Processing window 390/959
# Processing window 391/959
# Processing window 392/959
# Processing window 393/959
# Processing window 394/959
# Processing window 395/959
# Processing window 396/959
# Processing window 397/959
# Processing window 398/959
# Processing window 399/959
# Processing window 400/959
# Processing window 401/959
# Processing window 402/959
# Processing window 403/959
# Processing window 404/959
# Processing window 405/959
# Processing window 406/959
# Processing window 407/959
# Processing window 408/959
# Processing window 409/959
# Processing window 410/959
# Processing window 411/959
# Processing window 412/959
# Processing window 413/959
# Processing window 414/959
# Processing window 415/959
# Processing window 416/959
# Processing window 417/959
# Processing window 418/959
# Processing window 419/959
# Processing window 420/959
# Processing window 421/959
# Processing window 422/959
# Processing window 423/959
# Processing window 424/959
# Processing window 425/959
# Processing window 426/959
# Processing window 427/959
# Processing window 428/959
# Processing window 429/959
# Processing window 430/959
# Processing window 431/959
# Processing window 432/959
# Processing window 433/959
# Processing window 434/959
# Processing window 435/959
# Processing window 436/959
# Processing window 437/959
# Processing window 438/959
# Processing window 439/959
# Processing window 440/959
# Processing window 441/959
# Processing window 442/959
# Processing window 443/959
# Processing window 444/959
# Processing window 445/959
# Processing window 446/959
# Processing window 447/959
# Processing window 448/959
# Processing window 449/959
# Processing window 450/959
# Processing window 451/959
# Processing window 452/959
# Processing window 453/959
# Processing window 454/959
# Processing window 455/959
# Processing window 456/959
# Processing window 457/959
# Processing window 458/959
# Processing window 459/959
# Processing window 460/959
# Processing window 461/959
# Processing window 462/959
# Processing window 463/959
# Processing window 464/959
# Processing window 465/959
# Processing window 466/959
# Processing window 467/959
# Processing window 468/959
# Processing window 469/959
# Processing window 470/959
# Processing window 471/959
# Processing window 472/959
# Processing window 473/959
# Processing window 474/959
# Processing window 475/959
# Processing window 476/959
# Processing window 477/959
# Processing window 478/959
# Processing window 479/959
# Processing window 480/959
# Processing window 481/959
# Processing window 482/959
# Processing window 483/959
# Processing window 484/959
# Processing window 485/959
# Processing window 486/959
# Processing window 487/959
# Processing window 488/959
# Processing window 489/959
# Processing window 490/959
# Processing window 491/959
# Processing window 492/959
# Processing window 493/959
# Processing window 494/959
# Processing window 495/959
# Processing window 496/959
# Processing window 497/959
# Processing window 498/959
# Processing window 499/959
# Processing window 500/959
# Processing window 501/959
# Processing window 502/959
# Processing window 503/959
# Processing window 504/959
# Processing window 505/959
# Processing window 506/959
# Processing window 507/959
# Processing window 508/959
# Processing window 509/959
# Processing window 510/959
# Processing window 511/959
# Processing window 512/959
# Processing window 513/959
# Processing window 514/959
# Processing window 515/959
# Processing window 516/959
# Processing window 517/959
# Processing window 518/959
# Processing window 519/959
# Processing window 520/959
# Processing window 521/959
# Processing window 522/959
# Processing window 523/959
# Processing window 524/959
# Processing window 525/959
# Processing window 526/959
# Processing window 527/959
# Processing window 528/959
# Processing window 529/959
# Processing window 530/959
# Processing window 531/959
# Processing window 532/959
# Processing window 533/959
# Processing window 534/959
# Processing window 535/959
# Processing window 536/959
# Processing window 537/959
# Processing window 538/959
# Processing window 539/959
# Processing window 540/959
# Processing window 541/959
# Processing window 542/959
# Processing window 543/959
# Processing window 544/959
# Processing window 545/959
# Processing window 546/959
# Processing window 547/959
# Processing window 548/959
# Processing window 549/959
# Processing window 550/959
# Processing window 551/959
# Processing window 552/959
# Processing window 553/959
# Processing window 554/959
# Processing window 555/959
# Processing window 556/959
# Processing window 557/959
# Processing window 558/959
# Processing window 559/959
# Processing window 560/959
# Processing window 561/959
# Processing window 562/959
# Processing window 563/959
# Processing window 564/959
# Processing window 565/959
# Processing window 566/959
# Processing window 567/959
# Processing window 568/959
# Processing window 569/959
# Processing window 570/959
# Processing window 571/959
# Processing window 572/959
# Processing window 573/959
# Processing window 574/959
# Processing window 575/959
# Processing window 576/959
# Processing window 577/959
# Processing window 578/959
# Processing window 579/959
# Processing window 580/959
# Processing window 581/959
# Processing window 582/959
# Processing window 583/959
# Processing window 584/959
# Processing window 585/959
# Processing window 586/959
# Processing window 587/959
# Processing window 588/959
# Processing window 589/959
# Processing window 590/959
# Processing window 591/959
# Processing window 592/959
# Processing window 593/959
# Processing window 594/959
# Processing window 595/959
# Processing window 596/959
# Processing window 597/959
# Processing window 598/959
# Processing window 599/959
# Processing window 600/959
# Processing window 601/959
# Processing window 602/959
# Processing window 603/959
# Processing window 604/959
# Processing window 605/959
# Processing window 606/959
# Processing window 607/959
# Processing window 608/959
# Processing window 609/959
# Processing window 610/959
# Processing window 611/959
# Processing window 612/959
# Processing window 613/959
# Processing window 614/959
# Processing window 615/959
# Processing window 616/959
# Processing window 617/959
# Processing window 618/959
# Processing window 619/959
# Processing window 620/959
# Processing window 621/959
# Processing window 622/959
# Processing window 623/959
# Processing window 624/959
# Processing window 625/959
# Processing window 626/959
# Processing window 627/959
# Processing window 628/959
# Processing window 629/959
# Processing window 630/959
# Processing window 631/959
# Processing window 632/959
# Processing window 633/959
# Processing window 634/959
# Processing window 635/959
# Processing window 636/959
# Processing window 637/959
# Processing window 638/959
# Processing window 639/959
# Processing window 640/959
# Processing window 641/959
# Processing window 642/959
# Processing window 643/959
# Processing window 644/959
# Processing window 645/959
# Processing window 646/959
# Processing window 647/959
# Processing window 648/959
# Processing window 649/959
# Processing window 650/959
# Processing window 651/959
# Processing window 652/959
# Processing window 653/959
# Processing window 654/959
# Processing window 655/959
# Processing window 656/959
# Processing window 657/959
# Processing window 658/959
# Processing window 659/959
# Processing window 660/959
# Processing window 661/959
# Processing window 662/959
# Processing window 663/959
# Processing window 664/959
# Processing window 665/959
# Processing window 666/959
# Processing window 667/959
# Processing window 668/959
# Processing window 669/959
# Processing window 670/959
# Processing window 671/959
# Processing window 672/959
# Processing window 673/959
# Processing window 674/959
# Processing window 675/959
# Processing window 676/959
# Processing window 677/959
# Processing window 678/959
# Processing window 679/959
# Processing window 680/959
# Processing window 681/959
# Processing window 682/959
# Processing window 683/959
# Processing window 684/959
# Processing window 685/959
# Processing window 686/959
# Processing window 687/959
# Processing window 688/959
# Processing window 689/959
# Processing window 690/959
# Processing window 691/959
# Processing window 692/959
# Processing window 693/959
# Processing window 694/959
# Processing window 695/959
# Processing window 696/959
# Processing window 697/959
# Processing window 698/959
# Processing window 699/959
# Processing window 700/959
# Processing window 701/959
# Processing window 702/959
# Processing window 703/959
# Processing window 704/959
# Processing window 705/959
# Processing window 706/959
# Processing window 707/959
# Processing window 708/959
# Processing window 709/959
# Processing window 710/959
# Processing window 711/959
# Processing window 712/959
# Processing window 713/959
# Processing window 714/959
# Processing window 715/959
# Processing window 716/959
# Processing window 717/959
# Processing window 718/959
# Processing window 719/959
# Processing window 720/959
# Processing window 721/959
# Processing window 722/959
# Processing window 723/959
# Processing window 724/959
# Processing window 725/959
# Processing window 726/959
# Processing window 727/959
# Processing window 728/959
# Processing window 729/959
# Processing window 730/959
# Processing window 731/959
# Processing window 732/959
# Processing window 733/959
# Processing window 734/959
# Processing window 735/959
# Processing window 736/959
# Processing window 737/959
# Processing window 738/959
# Processing window 739/959
# Processing window 740/959
# Processing window 741/959
# Processing window 742/959
# Processing window 743/959
# Processing window 744/959
# Processing window 745/959
# Processing window 746/959
# Processing window 747/959
# Processing window 748/959
# Processing window 749/959
# Processing window 750/959
# Processing window 751/959
# Processing window 752/959
# Processing window 753/959
# Processing window 754/959
# Processing window 755/959
# Processing window 756/959
# Processing window 757/959
# Processing window 758/959
# Processing window 759/959
# Processing window 760/959
# Processing window 761/959
# Processing window 762/959
# Processing window 763/959
# Processing window 764/959
# Processing window 765/959
# Processing window 766/959
# Processing window 767/959
# Processing window 768/959
# Processing window 769/959
# Processing window 770/959
# Processing window 771/959
# Processing window 772/959
# Processing window 773/959
# Processing window 774/959
# Processing window 775/959
# Processing window 776/959
# Processing window 777/959
# Processing window 778/959
# Processing window 779/959
# Processing window 780/959
# Processing window 781/959
# Processing window 782/959
# Processing window 783/959
# Processing window 784/959
# Processing window 785/959
# Processing window 786/959
# Processing window 787/959
# Processing window 788/959
# Processing window 789/959
# Processing window 790/959
# Processing window 791/959
# Processing window 792/959
# Processing window 793/959
# Processing window 794/959
# Processing window 795/959
# Processing window 796/959
# Processing window 797/959
# Processing window 798/959
# Processing window 799/959
# Processing window 800/959
# Processing window 801/959
# Processing window 802/959
# Processing window 803/959
# Processing window 804/959
# Processing window 805/959
# Processing window 806/959
# Processing window 807/959
# Processing window 808/959
# Processing window 809/959
# Processing window 810/959
# Processing window 811/959
# Processing window 812/959
# Processing window 813/959
# Processing window 814/959
# Processing window 815/959
# Processing window 816/959
# Processing window 817/959
# Processing window 818/959
# Processing window 819/959
# Processing window 820/959
# Processing window 821/959
# Processing window 822/959
# Processing window 823/959
# Processing window 824/959
# Processing window 825/959
# Processing window 826/959
# Processing window 827/959
# Processing window 828/959
# Processing window 829/959
# Processing window 830/959
# Processing window 831/959
# Processing window 832/959
# Processing window 833/959
# Processing window 834/959
# Processing window 835/959
# Processing window 836/959
# Processing window 837/959
# Processing window 838/959
# Processing window 839/959
# Processing window 840/959
# Processing window 841/959
# Processing window 842/959
# Processing window 843/959
# Processing window 844/959
# Processing window 845/959
# Processing window 846/959
# Processing window 847/959
# Processing window 848/959
# Processing window 849/959
# Processing window 850/959
# Processing window 851/959
# Processing window 852/959
# Processing window 853/959
# Processing window 854/959
# Processing window 855/959
# Processing window 856/959
# Processing window 857/959
# Processing window 858/959
# Processing window 859/959
# Processing window 860/959
# Processing window 861/959
# Processing window 862/959
# Processing window 863/959
# Processing window 864/959
# Processing window 865/959
# Processing window 866/959
# Processing window 867/959
# Processing window 868/959
# Processing window 869/959
# Processing window 870/959
# Processing window 871/959
# Processing window 872/959
# Processing window 873/959
# Processing window 874/959
# Processing window 875/959
# Processing window 876/959
# Processing window 877/959
# Processing window 878/959
# Processing window 879/959
# Processing window 880/959
# Processing window 881/959
# Processing window 882/959
# Processing window 883/959
# Processing window 884/959
# Processing window 885/959
# Processing window 886/959
# Processing window 887/959
# Processing window 888/959
# Processing window 889/959
# Processing window 890/959
# Processing window 891/959
# Processing window 892/959
# Processing window 893/959
# Processing window 894/959
# Processing window 895/959
# Processing window 896/959
# Processing window 897/959
# Processing window 898/959
# Processing window 899/959
# Processing window 900/959
# Processing window 901/959
# Processing window 902/959
# Processing window 903/959
# Processing window 904/959
# Processing window 905/959
# Processing window 906/959
# Processing window 907/959
# Processing window 908/959
# Processing window 909/959
# Processing window 910/959
# Processing window 911/959
# Processing window 912/959
# Processing window 913/959
# Processing window 914/959
# Processing window 915/959
# Processing window 916/959
# Processing window 917/959
# Processing window 918/959
# Processing window 919/959
# Processing window 920/959
# Processing window 921/959
# Processing window 922/959
# Processing window 923/959
# Processing window 924/959
# Processing window 925/959
# Processing window 926/959
# Processing window 927/959
# Processing window 928/959
# Processing window 929/959
# Processing window 930/959
# Processing window 931/959
# Processing window 932/959
# Processing window 933/959
# Processing window 934/959
# Processing window 935/959
# Processing window 936/959
# Processing window 937/959
# Processing window 938/959
# Processing window 939/959
# Processing window 940/959
# Processing window 941/959
# Processing window 942/959
# Processing window 943/959
# Processing window 944/959
# Processing window 945/959
# Processing window 946/959
# Processing window 947/959
# Processing window 948/959
# Processing window 949/959
# Processing window 950/959
# Processing window 951/959
# Processing window 952/959
# Processing window 953/959
# Processing window 954/959
# Processing window 955/959
# Processing window 956/959
# Processing window 957/959
# Processing window 958/959
# Processing window 959/959

# %%
def count_distractions(window):
    return np.sum(window, axis=1)

error_test_windows_count = count_distractions(tc_windows)
print(f"{tc_windows.shape=}")
print(f"{error_test_windows_count.shape=}")
# Out:
# tc_windows.shape=(959, 100)
# error_test_windows_count.shape=(959,)

# %% [markdown]
# ## Experiment comparing only parts on the data signals

# %%
def classify_windows_e_only(e_windows, reference_kde_distracted, reference_kde_not_distracted):
    """
    Classify the windows as distracted or not distracted based only on the error signal (e_windows)
    by computing the KL divergence from reference KDEs (distracted and not distracted distributions).
    
    Parameters:
    e_windows (list of arrays): Test windows of the error signal.
    reference_kde_distracted (KernelDensity): KDE for the distracted state.
    reference_kde_not_distracted (KernelDensity): KDE for the non-distracted state.
    
    Returns:
    list: Labels for each window (1 = distracted, 0 = not distracted).
    """
    labels = np.zeros(len(e_windows)) 
    kl_dist_list = []
    kl_not_dist_list = []

    for i, e_window in enumerate(e_windows):
        # Reshape the current window data into a 2D array with a single feature
        
        # Fit KDE on the current window using only the error signal
        kde_window = KernelDensity(kernel='gaussian', bandwidth=0.02).fit(e_window[:,None])
        
        # Score samples (log likelihoods) for each window using only the error signal
        window_log_scores = kde_window.score_samples(e_window[:,None])
        distracted_log_scores = reference_kde_distracted.score_samples(e_window[:,None])
        not_distracted_log_scores = reference_kde_not_distracted.score_samples(e_window[:,None])
        
        # Convert log likelihoods to probabilities (exponentiate)
        window_probs = np.exp(window_log_scores)
        distracted_probs = np.exp(distracted_log_scores)
        not_distracted_probs = np.exp(not_distracted_log_scores)
        
        # Compute KL divergence between current window and reference KDEs
        kl_dist = sp.stats.entropy(window_probs, distracted_probs)
        kl_not_dist = sp.stats.entropy(window_probs, not_distracted_probs)
        
        # Classify based on which divergence is smaller
        labels[i] = int(kl_dist < kl_not_dist)

        kl_dist_list.append(kl_dist)
        kl_not_dist_list.append(kl_not_dist)
    
    return labels, kl_dist_list, kl_not_dist_list

# # Fit KDEs for distracted and non-distracted states using the 2D data
# kde_distracted_e = estimate_distribution_single(error_distracted, bandwidth=0.07)
# kde_not_distracted_e = estimate_distribution_single(error_not_distracted, bandwidth=0.07)

# # Classify test windows based on multivariate KDE (both error and control signals)
# test_labels, kl_dists, kl_not_dists = classify_windows_e_only(error_test_windows, kde_distracted_e, kde_not_distracted_e)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 51
#      48 kde_not_distracted_e = estimate_distribution_single(error_not_distracted, bandwidth=0.07)
#      50 # Classify test windows based on multivariate KDE (both error and control signals)
# ---> 51 test_labels, kl_dists, kl_not_dists = classify_windows_e_only(error_test_windows, kde_distracted_e, kde_not_distracted_e)
#
# Cell In[17], line 26, in classify_windows_e_only(e_windows, reference_kde_distracted, reference_kde_not_distracted)
#      24 # Score samples (log likelihoods) for each window using only the error signal
#      25 window_log_scores = kde_window.score_samples(e_window[:,None])
# ---> 26 distracted_log_scores = reference_kde_distracted.score_samples(e_window[:,None])
#      27 not_distracted_log_scores = reference_kde_not_distracted.score_samples(e_window[:,None])
#      29 # Convert log likelihoods to probabilities (exponentiate)
#
# File ~/Thesis/thesis/lib/python3.9/site-packages/sklearn/neighbors/_kde.py:272, in KernelDensity.score_samples(self, X)
#     270     N = self.tree_.sum_weight
#     271 atol_N = self.atol * N
# --> 272 log_density = self.tree_.kernel_density(
#     273     X,
#     274     h=self.bandwidth_,
#     275     kernel=self.kernel,
#     276     atol=atol_N,
#     277     rtol=self.rtol,
#     278     breadth_first=self.breadth_first,
#     279     return_log=True,
#     280 )
#     281 log_density -= np.log(N)
#     282 return log_density
#
# KeyboardInterrupt:

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.grid()

print(error_test_windows_count.shape)
print(len(error_test_windows_count))
print(f"{test_labels.shape}")
# Scatter plot, coloring points based on the label
plt.scatter(range(len(error_test_windows_count)), error_test_windows_count, 
            c=test_labels, cmap='bwr', label='Distraction Count', alpha=0.75)

# Labeling the plot
plt.xlabel('Window Index')
plt.ylabel('Count of Distractions')
plt.title('Distraction Count per Window')
plt.colorbar(label='Test Label (0 = No Distraction, 1 = Distraction)')
plt.show()
# Out:
# (959,)
# 959
# (959,)

# %% [markdown]
# ## Visualize errors

# %%
for i in range(10):
    color = 'green'
    if error_test_windows_count[i] > 20:
        color = 'red'
    plot_kde_histogram(u_test_windows[i], title='Example distribution', bandwidth=0.02, kde_color=color)

# %% [markdown]
# ## Plotting routines

# %%
# Plotting the distraction count
plt.figure(figsize=(12, 8))

# First plot: distraction count
plt.subplot(2, 1, 1)
plt.grid()
plt.scatter(range(len(error_test_windows_count)), error_test_windows_count, 
            c=test_labels, cmap='bwr', label='Distraction Count', alpha=0.75)
plt.xlabel('Window Index')
plt.ylabel('Count of Distractions')
plt.title('Distraction Count per Window')
plt.colorbar(label='Test Label (0 = No Distraction, 1 = Distraction)')

# Second plot: KL divergence to distracted KDE
plt.subplot(2, 1, 2)
plt.grid()
plt.scatter(range(len(kl_dists)), np.array(kl_dists) - np.array(kl_not_dists), 
            c=test_labels, cmap='bwr', alpha=0.75, label='Difference KL Divergence between estimated distribution and reference KDE (Distracted - Not Distracted)')
plt.xlabel('Window Index')
plt.ylabel('KL Divergence')
plt.title('KL Divergence to Distracted KDE per Window')
plt.colorbar(label='Test Label (0 = No Distraction, 1 = Distraction)')

# Adjust layout and show both plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Fit Gaussian (as opposed to KDE)

# %%
import numpy as np
from scipy.stats import multivariate_normal
from scipy.special import kl_div

def fit_gaussian(data):
    """
    Fit a multivariate Gaussian to the data.
    
    Parameters:
    data (array-like): 2D array of shape (n_samples, n_features).
    
    Returns:
    tuple: Mean vector and covariance matrix of the Gaussian.
    """
    mean = np.mean(data, axis=0)
    covariance = np.cov(data, rowvar=False)
    return mean, covariance

def kl_divergence_gaussian(mean1, cov1, mean2, cov2):
    """
    Compute the KL divergence between two multivariate Gaussians.
    
    Parameters:
    mean1, mean2 (array-like): Mean vectors of the Gaussians.
    cov1, cov2 (array-like): Covariance matrices of the Gaussians.
    
    Returns:
    float: KL divergence between the two Gaussian distributions.
    """
    dist1 = multivariate_normal(mean=mean1, cov=cov1)
    dist2 = multivariate_normal(mean=mean2, cov=cov2)
    
    def kl_divergence_single_point(x):
        p_x = dist1.pdf(x)
        q_x = dist2.pdf(x)
        return kl_div(p_x, q_x)
    
    # Grid for evaluation
    grid = np.random.multivariate_normal(mean1, cov1, size=1000)
    kl_divergences = np.array([kl_divergence_single_point(x) for x in grid])
    
    # Average KL divergence
    return np.mean(kl_divergences)

def classify_windows(e_windows, u_windows, mean_distracted, cov_distracted, mean_not_distracted, cov_not_distracted):
    """
    Classify the windows as distracted or not distracted based on KL divergence
    from reference Gaussian distributions (distracted and not distracted distributions).
    
    Parameters:
    e_windows (list of arrays): Test windows of the error signal.
    u_windows (list of arrays): Test windows of the control input signal.
    mean_distracted (array-like): Mean vector for the distracted state.
    cov_distracted (array-like): Covariance matrix for the distracted state.
    mean_not_distracted (array-like): Mean vector for the non-distracted state.
    cov_not_distracted (array-like): Covariance matrix for the non-distracted state.
    
    Returns:
    list: Labels for each window (1 = distracted, 0 = not distracted).
    """
    labels = np.zeros(len(e_windows)) 
    kl_dist_list = []
    kl_not_dist_list = []

    for i in range(len(e_windows)):
        # Stack e and u into a multivariate window of shape (window_size, 2)
        window_data = np.column_stack((e_windows[i], u_windows[i]))  # Combine e and u

        # Fit Gaussian to the current window
        mean_window, cov_window = fit_gaussian(window_data)
        
        # Compute KL divergence between current window and reference Gaussians
        kl_dist = kl_divergence_gaussian(mean_window, cov_window, mean_distracted, cov_distracted)
        kl_not_dist = kl_divergence_gaussian(mean_window, cov_window, mean_not_distracted, cov_not_distracted)
        
        # Classify based on which divergence is smaller
        labels[i] = int(kl_dist < kl_not_dist)

        kl_dist_list.append(kl_dist)
        kl_not_dist_list.append(kl_not_dist)
    
    return labels, kl_dist_list, kl_not_dist_list

# Fit Gaussians for distracted and non-distracted states using the 2D data
mean_distracted, cov_distracted = fit_gaussian(input_distracted)
mean_not_distracted, cov_not_distracted = fit_gaussian(input_not_distracted)

# Classify test windows based on multivariate Gaussian models (both error and control signals)
test_labels, kl_dists, kl_not_dists = classify_windows(error_test_windows, u_test_windows, mean_distracted, cov_distracted, mean_not_distracted, cov_not_distracted)

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.grid()
# Scatter plot, coloring points based on the label
plt.scatter(range(len(error_test_windows_count)), error_test_windows_count, 
            c=test_labels, cmap='bwr', label='Distraction Count', alpha=0.75)

# Labeling the plot
plt.xlabel('Window Index')
plt.ylabel('Count of Distractions')
plt.title('Distraction Count per Window')
plt.colorbar(label='Test Label (0 = No Distraction, 1 = Distraction)')
plt.show()

# %%
# Plotting the distraction count
plt.figure(figsize=(12, 8))

# First plot: distraction count
plt.subplot(2, 1, 1)
plt.grid()
plt.scatter(range(len(error_test_windows_count)), error_test_windows_count, 
            c=test_labels, cmap='bwr', label='Distraction Count', alpha=0.75)
plt.xlabel('Window Index')
plt.ylabel('Count of Distractions')
plt.title('Distraction Count per Window')
plt.colorbar(label='Test Label (0 = No Distraction, 1 = Distraction)')

# Second plot: KL divergence to distracted KDE
plt.subplot(2, 1, 2)
plt.grid()
plt.scatter(range(len(kl_dists)), np.array(kl_dists) - np.array(kl_not_dists), 
            c=test_labels, cmap='bwr', alpha=0.75, label='KL Divergence to Distracted')
plt.xlabel('Window Index')
plt.ylabel('KL Divergence')
plt.title('KL Divergence to Distracted KDE per Window')
plt.colorbar(label='Test Label (0 = No Distraction, 1 = Distraction)')

# draw an horizontal line at y=-2
plt.axhline(y=-2, color='r', linestyle='--')

# Adjust layout and show both plots
plt.tight_layout()
plt.show()
